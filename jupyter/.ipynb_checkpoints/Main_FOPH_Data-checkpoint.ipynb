# %%
import pandas as pd
# %matplotlib inline

# %% [markdown]
# ### LOADING OF DATA

# %%
#loading of the data
#try except so it works on both of our computers
try:
    #HannahFolder
    DATA_FOLDER = 'T:\\2021-10-22_10-03-52_BAGEPI-1086-cortes_study_data_cases.csv'
    DATA = pd.read_csv(DATA_FOLDER, sep=';')
except:
    #MathiasFolder
    DATA_FOLDER = '2021-10-22_10-03-52_BAGEPI-1086-cortes_study_data_cases.csv'
    DATA = pd.read_csv(DATA_FOLDER, sep=';')

DATA.columns = ["ID" , "Case_dt", "Age", "Sex", "Kanton", "MuniName", 
       "MuniZIP", "VaccD1_dt", "VaccD2_dt", "VaccStatus", "Dead", "Death_dt", 
       "Hosp_dt", "Infection_dt"]
DATA
# Out:
# /Users/mathiasnuris/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (7,8) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#                                           ID     Case_dt   Age       Sex  \
# 0       3ede48f3-ff2d-4676-8a7c-517a320ff62e  2020-02-24  70.0  Männlich
# 1       a5ab42b7-188d-437c-a7a8-cc573fd36488  2020-02-25  25.0  Männlich
# 2       7206a959-7ea9-4d41-9bd8-5e246339269e  2020-02-26   2.0  Männlich
# 3       183b5a64-34f2-4de5-9e49-3b29d604101f  2020-02-26   0.0  Männlich
# 4       e1900c37-23f5-4e9e-a817-7e30513ae17a  2020-02-26  28.0  Männlich
# ...                                      ...         ...   ...       ...
# 738593  777bc8e4-7871-4dbf-8db8-33e4fa7117d6  2021-08-15  60.0  Weiblich
# 738594  e1320311-4864-4f05-a21b-f77b0fa9adab  2021-08-15  67.0  Weiblich
# 738595  ad9e67b8-f4c8-4644-8f90-0ec06e415b51  2021-08-15  39.0  Weiblich
# 738596  fe2f77c7-08c9-4d00-818e-83c4175d9157  2021-08-15  13.0  Weiblich
# 738597  921fbc52-60b1-4044-ad57-1711608db79e  2021-08-15  69.0  Männlich
#
#        Kanton         MuniName  MuniZIP   VaccD1_dt   VaccD2_dt  \
# 0          TI           Lugano   5192.0         NaN         NaN
# 1          AG  Möriken-Wildegg   4203.0         NaN         NaN
# 2          GR              NaN      NaN         NaN         NaN
# 3          GR              NaN      NaN         NaN         NaN
# 4          GE           Genève   6621.0         NaN         NaN
# ...       ...              ...      ...         ...         ...
# 738593     ZH      Glattfelden     58.0         NaN         NaN
# 738594     ZH          Opfikon     66.0         NaN         NaN
# 738595     ZH           Zürich    261.0         NaN         NaN
# 738596     LU             Rain   1037.0         NaN         NaN
# 738597     BL       Lampenberg   2887.0  2021-05-18  2021-06-15
#
#               VaccStatus  Dead Death_dt     Hosp_dt Infection_dt
# 0                unknown   NaN      NaN  2020-02-24   2020-02-24
# 1                unknown   NaN      NaN  2020-02-25   2020-02-26
# 2                unknown   NaN      NaN  2020-02-26   2020-02-26
# 3                unknown   NaN      NaN  2020-02-26   2020-02-26
# 4                unknown   NaN      NaN         NaN   2020-02-26
# ...                  ...   ...      ...         ...          ...
# 738593    not_vaccinated   NaN      NaN  2021-08-18   2021-08-15
# 738594           unknown   NaN      NaN         NaN   2021-08-16
# 738595           unknown   NaN      NaN         NaN   2021-08-15
# 738596           unknown   NaN      NaN         NaN   2021-08-15
# 738597  fully_vaccinated   NaN      NaN         NaN   2021-08-15
#
# [738598 rows x 14 columns]

# %% [markdown]
# ### LOADING DATA ON COMMUNITIES

# %%
#loading of the data
#try except so it works on both of our computers
try:
    #HannahFolder
    path = '..'
    municipalities_data = pd.read_excel(path, sheet_name='Sheet1')
except:
    #MathiasFolder
    path = '/Users/mathiasnuris/Documents/EPFL/MA3/Lab_Immersion/Data/Add_comunitites/DataCommunities.xlsx'
    municipalities_data = pd.read_excel(path, sheet_name='Sheet1')

municipalities_data.columns = ["MuniZIP" , "MuniName", "NbrResident", "Change%", "PopDensitiyPer_km²", "Strangers%", 
       "Pop%[0-19]", "Pop%[20-64]", "Pop%[65-..]", "MarriageRate", "DivorceRate", "NatalityRate", "MortalityRate",
       "PrivateHouseholds", "MeanSizeHouseholdsPerPerson", "TotSurfacePer_km²", "HabitationInfrastructureSurface%", 
       "HabInfraSurface_VariationHa", "AgricolSurface%", "AgriSurface_VariationHa", "WoodenSurface%", "ImproductiveSurface%",
       "TotalEmplois", "Employement1Sector", "Employement2Sector", "Employement3Sector", "TotalEtablissement", 
       "Etablissement1Sector", "Etablissement2Sector", "Etablissement3Sector", "VacantUnitsRate", "NewHomes1000habs", 
       "SocialSecurityRate", "PLR", "PDC","PS","UDC","PEV/PCS","PVL","PBD","PST","PES","SmallRightParties"]

municipalities_data = municipalities_data.drop('MuniName', axis=1)
municipalities_data
# Out:
#       MuniZIP  NbrResident    Change%  PopDensitiyPer_km²  Strangers%  \
# 0         NaN      8606033   9.400000          215.200000   25.300000
# 1         1.0         1981   8.607456          250.442478   14.184755
# 2         2.0        12303  10.927779         1161.756374   28.700317
# 3         3.0         5572   8.005427          749.932705   16.564968
# 4         4.0         3751  11.636905          275.808824   16.022394
# ...       ...          ...        ...                 ...         ...
# 2168   6806.0          559   1.821494           61.092896    7.155635
# 2169   6807.0         1238  -5.279265           53.732639    9.127625
# 2170   6808.0         1263   0.158604           20.453441    7.284244
# 2171   6809.0         1085  -6.060606           26.508673    8.387097
# 2172   6810.0         1142  -3.952902           36.755713    5.954466
#
#       Pop%[0-19]  Pop%[20-64]  Pop%[65-..]  MarriageRate  DivorceRate  ...  \
# 0      20.000000    61.400000    18.700000      4.500000     2.000000  ...
# 1      19.787986    62.190813    18.021201      7.065355     2.018673  ...
# 2      20.165813    61.667886    18.166301      5.543780     1.793576  ...
# 3      23.636037    59.834889    16.529074      4.316547     1.798561  ...
# 4      22.180752    59.824047    17.995201      3.220612     1.610306  ...
# ...          ...          ...          ...           ...          ...  ...
# 2168   18.425760    56.887299    24.686941      7.279345     0.000000  ...
# 2169   21.728595    52.988691    25.282714      4.051864     0.810373  ...
# 2170   18.289786    56.611243    25.098971      3.138486     1.569243  ...
# 2171   17.788018    55.483871    26.728111      5.504587     1.834862  ...
# 2172   21.366025    54.028021    24.605954      1.736111     1.736111  ...
#
#           PLR      PDC       PS      UDC  PEV/PCS      PVL      PBD       PST  \
# 0        15.1     11.4     16.8     25.6      2.3      7.8      2.4         1
# 1      16.421  2.49797  11.5651   30.381  3.22747  14.3173  1.26372   0.16211
# 2     13.3854  4.53534  14.6453  30.3069  6.61856  12.6666  2.00145  0.198718
# 3      15.355  3.86796  16.7429  26.1163  4.19402  16.2379  1.28403  0.176013
# 4     11.1352  3.93455  13.7115  33.1848  4.05976   12.417  1.61075   0.19312
# ...       ...      ...      ...      ...      ...      ...      ...       ...
# 2168  19.0698  22.7907   17.907  21.1628  9.76744        *        *         *
# 2169   13.758  40.1274  23.5669  11.7197  3.82166        *        *         *
# 2170  4.48239  33.2978  21.5582   14.301  10.2455        *        *         *
# 2171  8.39002  37.8685  19.3878  18.7075  4.19501        *        *         *
# 2172  13.7738  27.6596  16.3494  20.2688  9.18253        *        *         *
#
#           PES  SmallRightParties
# 0        13.2                2.1
# 1     15.0505            3.82065
# 2     12.5906            1.55552
# 3     12.3685            1.38502
# 4     16.7441            1.61075
# ...       ...                ...
# 2168  9.30233                  *
# 2169  7.00637                  *
# 2170  16.1153                  *
# 2171  11.4512                  *
# 2172   12.766                  *
#
# [2173 rows x 42 columns]

# %% [markdown]
# ### MERGING SOCIO-ECO DATASETS ACCORDING TO 'MuniZIP'

# %%
merge = pd.merge(DATA, municipalities_data, left_on='MuniZIP', right_on='MuniZIP', how='inner')
merge
# Out:
#                                           ID     Case_dt   Age       Sex  \
# 0       3ede48f3-ff2d-4676-8a7c-517a320ff62e  2020-02-24  70.0  Männlich
# 1       34c16d61-49b4-4fc8-8375-6025b8a27fa0  2020-03-01  81.0  Männlich
# 2       f6c98490-e001-4e6d-9444-ec898de23b40  2020-03-02  50.0  Weiblich
# 3       1db5127e-9df7-4ce2-a031-d6f7fdffe532  2020-03-02  47.0  Weiblich
# 4       9f724fa8-4a4b-4e77-b5a5-fef7aecdfd39  2020-03-02  64.0  Männlich
# ...                                      ...         ...   ...       ...
# 734604  63ffcdea-8151-424a-872b-89a3321c7a0a  2021-02-15  23.0  Männlich
# 734605  86ae4fff-6c52-4a08-a027-4bc29ca018c0  2021-03-23  45.0  Männlich
# 734606  34627bc7-1f19-4dbd-8279-7966a9059bab  2021-04-01  32.0  Weiblich
# 734607  234ca50b-22ec-46e0-812a-d6d662845267  2021-04-07  40.0  Weiblich
# 734608  615f5401-e44a-4eb6-af54-a436dd69b020  2021-04-07  35.0  Männlich
#
#        Kanton      MuniName  MuniZIP VaccD1_dt VaccD2_dt VaccStatus  ...  \
# 0          TI        Lugano   5192.0       NaN       NaN    unknown  ...
# 1          TI        Lugano   5192.0       NaN       NaN    unknown  ...
# 2          TI        Lugano   5192.0       NaN       NaN    unknown  ...
# 3          TI        Lugano   5192.0       NaN       NaN    unknown  ...
# 4          TI        Lugano   5192.0       NaN       NaN    unknown  ...
# ...       ...           ...      ...       ...       ...        ...  ...
# 734604     VS  Zwischbergen   6011.0       NaN       NaN    unknown  ...
# 734605     BE   Willadingen    423.0       NaN       NaN    unknown  ...
# 734606     BE   Willadingen    423.0       NaN       NaN    unknown  ...
# 734607     VS          Binn   6054.0       NaN       NaN    unknown  ...
# 734608     VS          Binn   6054.0       NaN       NaN    unknown  ...
#
#              PLR       PDC       PS      UDC  PEV/PCS      PVL      PBD  \
# 0        20.3399   13.9847   13.917   13.148        *  1.01226        *
# 1        20.3399   13.9847   13.917   13.148        *  1.01226        *
# 2        20.3399   13.9847   13.917   13.148        *  1.01226        *
# 3        20.3399   13.9847   13.917   13.148        *  1.01226        *
# 4        20.3399   13.9847   13.917   13.148        *  1.01226        *
# ...          ...       ...      ...      ...      ...      ...      ...
# 734604   1.67364   37.2385  1.25523  58.5774        0        0        *
# 734605   4.66563  0.583204  8.20373  60.4588  1.01089  7.89269  9.52566
# 734606   4.66563  0.583204  8.20373  60.4588  1.01089  7.89269  9.52566
# 734607  0.488998   73.1051  3.42298  17.1149        0        0        *
# 734608  0.488998   73.1051  3.42298  17.1149        0        0        *
#
#              PST      PES  SmallRightParties
# 0       0.903688   11.139            21.5938
# 1       0.903688   11.139            21.5938
# 2       0.903688   11.139            21.5938
# 3       0.903688   11.139            21.5938
# 4       0.903688   11.139            21.5938
# ...          ...      ...                ...
# 734604         *  1.25523                  *
# 734605         0    5.521           0.972006
# 734606         0    5.521           0.972006
# 734607         *  5.86797                  *
# 734608         *  5.86797                  *
#
# [734609 rows x 55 columns]

# %% [markdown]
# ### MERGING GPS DATASETS ACCORDING TO 'MuniZIP'

# %%
#loading of the data
#try except so it works on both of our computers
try:
    #HannahFolder
    path = '..'
    GPS_coordinates = pd.read_excel(path, sheet_name='Sheet1')
except:
    #MathiasFolder
    path = '/Users/mathiasnuris/Documents/EPFL/MA3/Lab_Immersion/Data/Add_comunitites/try.csv'
    GPS_coordinates = pd.read_csv(path, sep=',')
GPS_coordinates = GPS_coordinates[GPS_coordinates['country code']=='CH']
GPS_coordinates['communitycode'] = GPS_coordinates['communitycode'].astype(float, errors = 'raise')
GPS_coordinates['longitude'] = GPS_coordinates['longitude'].astype(float, errors = 'raise')
GPS_coordinates
# Out:
# /Users/mathiasnuris/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (1,4,6,7,8,10,11) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#        country code postal code                place                state  \
# 0                AD       AD100              Canillo              Canillo
# 1                AD       AD200               Encamp               Encamp
# 2                AD       AD400           La Massana           La Massana
# 3                AD       AD300               Ordino               Ordino
# 4                AD       AD600  Sant Julià de Lòria  Sant Julià de Lòria
# ...             ...         ...                  ...                  ...
# 676926           UA       13654         Мовчанівське          Zhytomyrska
# 676927           UA       13655           Причепівка          Zhytomyrska
# 676928           UA       13656               Чехова          Zhytomyrska
# 676929           UA       13657            Котелянка          Zhytomyrska
# 676930           VA         120  Citta' Del Vaticano                  NaN
#
#        statecode province_or_county province_or_countycode community  \
# 0              2                NaN                    NaN       NaN
# 1              3                NaN                    NaN       NaN
# 2              4                NaN                    NaN       NaN
# 3              5                NaN                    NaN       NaN
# 4              6                NaN                    NaN       NaN
# ...          ...                ...                    ...       ...
# 676926        27         Ruzhynskyi                    NaN       NaN
# 676927        27         Ruzhynskyi                    NaN       NaN
# 676928        27         Ruzhynskyi                    NaN       NaN
# 676929        27         Ruzhynskyi                    NaN       NaN
# 676930       NaN                NaN                    NaN       NaN
#
#        communitycode  latitude longitude accuracy  Country Continent;
# 0                NaN   42.5833    1.6667        6  Andorra    Europe;
# 1                NaN   42.5333    1.6333        6  Andorra    Europe;
# 2                NaN   42.5667    1.4833        6  Andorra    Europe;
# 3                NaN   42.6000      1.55        6  Andorra    Europe;
# 4                NaN   42.4667       1.5        6  Andorra    Europe;
# ...              ...       ...       ...      ...      ...        ...
# 676926           NaN   49.6877   29.3716        4  Ukraine    Europe;
# 676927           NaN   49.6740   29.4591        4  Ukraine    Europe;
# 676928           NaN   49.6686   29.3993        4  Ukraine    Europe;
# 676929           NaN   49.6651   29.0552        4  Ukraine    Europe;
# 676930           NaN   41.9024   12.4533        4  Vatican    Europe;
#
# [676931 rows x 14 columns]

# %%
copy = GPS_coordinates[['communitycode','latitude', 'longitude']]
copy = copy.drop_duplicates(subset=['communitycode'], keep='last')
final = pd.merge(merge, copy, left_on='MuniZIP', right_on='communitycode', how='inner')
final = final.drop('communitycode', axis=1)
final
# Out:
# <ipython-input-113-8ad5abafc49a>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   GPS_coordinates['communitycode'] = GPS_coordinates['communitycode'].astype(float, errors = 'raise')
# <ipython-input-113-8ad5abafc49a>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   GPS_coordinates['longitude'] = GPS_coordinates['longitude'].astype(float, errors = 'raise')
#       country code postal code              place          state statecode  \
# 30217           CH        5000              Aarau  Kanton Aargau        AG
# 30218           CH        5001            Aarau 1  Kanton Aargau        AG
# 30219           CH        5004              Aarau  Kanton Aargau        AG
# 30220           CH        5017         Barmelweid  Kanton Aargau        AG
# 30221           CH        5018         Erlinsbach  Kanton Aargau        AG
# ...            ...         ...                ...            ...       ...
# 34568           CH        8092             Zürich  Kanton Zürich        ZH
# 34569           CH        8093             Zürich  Kanton Zürich        ZH
# 34570           CH        8096  Zürich IBRS local  Kanton Zürich        ZH
# 34571           CH        8098             Zürich  Kanton Zürich        ZH
# 34572           CH        8099             Zürich  Kanton Zürich        ZH
#
#       province_or_county province_or_countycode        community  \
# 30217       Bezirk Aarau                   1901            Aarau
# 30218       Bezirk Aarau                   1901            Aarau
# 30219       Bezirk Aarau                   1901            Aarau
# 30220       Bezirk Aarau                   1901  Erlinsbach (AG)
# 30221       Bezirk Aarau                   1901  Erlinsbach (AG)
# ...                  ...                    ...              ...
# 34568      Bezirk Zürich                    112           Zürich
# 34569      Bezirk Zürich                    112           Zürich
# 34570      Bezirk Zürich                    112           Zürich
# 34571      Bezirk Zürich                    112           Zürich
# 34572      Bezirk Zürich                    112           Zürich
#
#        communitycode  latitude  longitude accuracy      Country Continent;
# 30217         4001.0   47.3925     8.0442        4  Switzerland    Europe;
# 30218         4001.0   47.3888     8.0483      NaN  Switzerland    Europe;
# 30219         4001.0   47.3925     8.0442        4  Switzerland    Europe;
# 30220         4005.0   47.4159     7.9764        4  Switzerland    Europe;
# 30221         4005.0   47.4052     8.0151        4  Switzerland    Europe;
# ...              ...       ...        ...      ...          ...        ...
# 34568          261.0   47.3828     8.5307      NaN  Switzerland    Europe;
# 34569          261.0   47.3828     8.5307      NaN  Switzerland    Europe;
# 34570          261.0   47.3828     8.5307      NaN  Switzerland    Europe;
# 34571          261.0   47.3828     8.5307      NaN  Switzerland    Europe;
# 34572          261.0   47.3828     8.5307      NaN  Switzerland    Europe;
#
# [4356 rows x 14 columns]

# %%
final.columns
# Out:
#                                            ID     Case_dt   Age       Sex  \
# 0        3ede48f3-ff2d-4676-8a7c-517a320ff62e  2020-02-24  70.0  Männlich
# 1        3ede48f3-ff2d-4676-8a7c-517a320ff62e  2020-02-24  70.0  Männlich
# 2        3ede48f3-ff2d-4676-8a7c-517a320ff62e  2020-02-24  70.0  Männlich
# 3        3ede48f3-ff2d-4676-8a7c-517a320ff62e  2020-02-24  70.0  Männlich
# 4        3ede48f3-ff2d-4676-8a7c-517a320ff62e  2020-02-24  70.0  Männlich
# ...                                       ...         ...   ...       ...
# 5828843  63ffcdea-8151-424a-872b-89a3321c7a0a  2021-02-15  23.0  Männlich
# 5828844  86ae4fff-6c52-4a08-a027-4bc29ca018c0  2021-03-23  45.0  Männlich
# 5828845  34627bc7-1f19-4dbd-8279-7966a9059bab  2021-04-01  32.0  Weiblich
# 5828846  234ca50b-22ec-46e0-812a-d6d662845267  2021-04-07  40.0  Weiblich
# 5828847  615f5401-e44a-4eb6-af54-a436dd69b020  2021-04-07  35.0  Männlich
#
#         Kanton      MuniName  MuniZIP VaccD1_dt VaccD2_dt VaccStatus  ...  \
# 0           TI        Lugano   5192.0       NaN       NaN    unknown  ...
# 1           TI        Lugano   5192.0       NaN       NaN    unknown  ...
# 2           TI        Lugano   5192.0       NaN       NaN    unknown  ...
# 3           TI        Lugano   5192.0       NaN       NaN    unknown  ...
# 4           TI        Lugano   5192.0       NaN       NaN    unknown  ...
# ...        ...           ...      ...       ...       ...        ...  ...
# 5828843     VS  Zwischbergen   6011.0       NaN       NaN    unknown  ...
# 5828844     BE   Willadingen    423.0       NaN       NaN    unknown  ...
# 5828845     BE   Willadingen    423.0       NaN       NaN    unknown  ...
# 5828846     VS          Binn   6054.0       NaN       NaN    unknown  ...
# 5828847     VS          Binn   6054.0       NaN       NaN    unknown  ...
#
#              UDC  PEV/PCS      PVL      PBD       PST      PES  \
# 0         13.148        *  1.01226        *  0.903688   11.139
# 1         13.148        *  1.01226        *  0.903688   11.139
# 2         13.148        *  1.01226        *  0.903688   11.139
# 3         13.148        *  1.01226        *  0.903688   11.139
# 4         13.148        *  1.01226        *  0.903688   11.139
# ...          ...      ...      ...      ...       ...      ...
# 5828843  58.5774        0        0        *         *  1.25523
# 5828844  60.4588  1.01089  7.89269  9.52566         0    5.521
# 5828845  60.4588  1.01089  7.89269  9.52566         0    5.521
# 5828846  17.1149        0        0        *         *  5.86797
# 5828847  17.1149        0        0        *         *  5.86797
#
#          SmallRightParties  communitycode  latitude  longitude
# 0                  21.5938         5192.0   46.0101     8.9600
# 1                  21.5938         5192.0   46.0055     8.9714
# 2                  21.5938         5192.0   46.0055     8.9714
# 3                  21.5938         5192.0   46.0055     8.9714
# 4                  21.5938         5192.0   46.0055     8.9714
# ...                    ...            ...       ...        ...
# 5828843                  *         6011.0   46.1964     8.1388
# 5828844           0.972006          423.0   47.1467     7.6111
# 5828845           0.972006          423.0   47.1467     7.6111
# 5828846                  *         6054.0   46.3639     8.1842
# 5828847                  *         6054.0   46.3639     8.1842
#
# [5828848 rows x 58 columns]
